# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('Rohdaten Aufgabe 2 - Kandidatenversion.xlsx')

# %%
df
# Out:
#       Kürzel E1    Bereich E1 Kürzel E2               Bereich E2  \
# 0          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 1          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 2          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 3          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 4          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# ...         ...           ...       ...                      ...
# 86283       ERG      Ergebnis    ERGROH                Rohertrag
# 86284       ERG      Ergebnis    ERGROH                Rohertrag
# 86285       ERG      Ergebnis    ERGROH                Rohertrag
# 86286       ERG      Ergebnis    ERGROH                Rohertrag
# 86287       ERG      Ergebnis    ERGROH                Rohertrag
#
#                            Ausprägung Name                ZEIT      NR  \
# 0      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-08-26 10:17:01    1926
# 1      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-09-22 11:02:31   13499
# 2      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 13:03:47   23214
# 3      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 15:16:31   23293
# 4      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-22 14:52:39   24745
# ...                               ...  ...                 ...     ...
# 86283                       Rohertrag  NaN 2021-07-29 14:43:05  109045
# 86284                       Rohertrag  NaN 2021-07-29 15:22:45  109082
# 86285                       Rohertrag  NaN 2021-08-16 09:27:11  113274
# 86286                       Rohertrag  NaN 2021-08-16 23:00:25  113658
# 86287                       Rohertrag  NaN 2021-08-27 14:09:43  116653
#
#            MONAT User Pseudo                   ABTEILUNG  \
# 0     2020-08-01    User_104                     Einkauf
# 1     2020-09-01    User_404                     Einkauf
# 2     2020-10-01     User_85                 Controlling
# 3     2020-10-01    User_206                 Controlling
# 4     2020-10-01     User_85                 Controlling
# ...          ...         ...                         ...
# 86283 2021-07-01    User_287                 Controlling
# 86284 2021-07-01    User_287                 Controlling
# 86285 2021-08-01    User_290  Finanz- und Rechnungswesen
# 86286 2021-08-01     User_80                     Verkauf
# 86287 2021-08-01    User_233                     Einkauf
#
#                                   BERICHT  IST_KONZERNBERICHT  Anzahl
# 0      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 1      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 2      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 3      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 4      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# ...                                   ...                 ...     ...
# 86283                       Rohertrag.pdf                   0       1
# 86284                       Rohertrag.pdf                   0       1
# 86285                       Rohertrag.pdf                   0       1
# 86286                       Rohertrag.pdf                   0       1
# 86287                       Rohertrag.pdf                   0       1
#
# [86288 rows x 14 columns]

# %%
df.describe(include='object')
# Out:
#        Kürzel E1 Bereich E1 Kürzel E2  Bereich E2  Ausprägung       Name  \
# count      86288      86288     86288       86288       86288      50269
# unique         5          5        32          32         281         17
# top          WAR       Ware    WARTAG  Tagesschau  TAGROH200D  TAFIAR200
# freq       42950      42950     12070       12070       10177      12066
#
#        User Pseudo ABTEILUNG         BERICHT
# count        86288     86288           86288
# unique         422        20             281
# top       User_310   Einkauf  TAGROH200D.pdf
# freq          3098     51410           10177

# %%
df.describe()
# Out:
#                   NR  IST_KONZERNBERICHT   Anzahl
# count   86288.000000        86288.000000  86288.0
# mean    58600.742954            0.025936      1.0
# std     33891.254781            0.158947      0.0
# min        39.000000            0.000000      1.0
# 25%     29021.500000            0.000000      1.0
# 50%     58037.000000            0.000000      1.0
# 75%     88036.250000            0.000000      1.0
# max    117102.000000            1.000000      1.0

# %%
df.isnull().sum()
# Out:
# Kürzel E1                 0
# Bereich E1                0
# Kürzel E2                 0
# Bereich E2                0
# Ausprägung                0
# Name                  36019
# ZEIT                      0
# NR                        0
# MONAT                     0
# User Pseudo               0
# ABTEILUNG                 0
# BERICHT                   0
# IST_KONZERNBERICHT        0
# Anzahl                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86288 entries, 0 to 86287
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Kürzel E1           86288 non-null  object
#  1   Bereich E1          86288 non-null  object
#  2   Kürzel E2           86288 non-null  object
#  3   Bereich E2          86288 non-null  object
#  4   Ausprägung          86288 non-null  object
#  5   Name                50269 non-null  object
#  6   ZEIT                86288 non-null  datetime64[ns]
#  7   NR                  86288 non-null  int64
#  8   MONAT               86288 non-null  datetime64[ns]
#  9   User Pseudo         86288 non-null  object
#  10  ABTEILUNG           86288 non-null  object
#  11  BERICHT             86288 non-null  object
#  12  IST_KONZERNBERICHT  86288 non-null  int64
#  13  Anzahl              86288 non-null  int64
# dtypes: datetime64[ns](2), int64(3), object(9)
# memory usage: 9.2+ MB

# %%
df['Kürzel E1'].value_counts()
# Out:
# WAR     42950
# UMS     29053
# ESHP     9015
# KST      3143
# ERG      2127
# Name: Kürzel E1, dtype: int64

# %%
df['Bereich E1'].value_counts()
# Out:
# Ware                 42950
# Umsatz und Absatz    29053
# eShop-Portal          9015
# Kosten                3143
# Ergebnis              2127
# Name: Bereich E1, dtype: int64

# %%
df['Kürzel E2'].value_counts()
# Out:
# WARTAG           12070
# WARKLK           11799
# KSTTAGROH        11615
# UMSTAGUMS         8709
# WARALTSTR         8699
# WARUMSABS         7637
# ESHUMS            5121
# UMSENTVGL         3155
# ESHERG            2607
# EXPANS            2485
# KSTPERS           2214
# ERGGUV            1223
# WARRED            1212
# WARBESTPBC023     1211
# ESHWAR            1093
# UMSHOCHR           953
# UMSKUNFRE          884
# ERGDB              734
# UMSINDEX           696
# INVEST             488
# WARBESTLD          322
# UMSENTJUN          277
# KSTLOG             209
# ESHKST             194
# ERGROH             170
# KSTABW             167
# UMSTAGABS          146
# UMSVGLBRA           95
# KSTWERB             60
# UMSTAGGEB           27
# UMSBONANALYSE       11
# KSTREISE             5
# Name: Kürzel E2, dtype: int64

# %%
df['Bereich E2'].value_counts()
# Out:
# Tagesschau                       12070
# Kalkulation                      11799
# Tagesrohertrag                   11615
# Tagesumsatz                       8709
# Altersstruktur                    8699
# Umsatz und Absatz                 7637
# Umsatz und Absatz eShop           5121
# Umsatz + Paarzahl GL              3155
# Ergebnis eShop                    2607
# Expansion                         2485
# Personal                          2214
# GuV                               1223
# Preisreduzierungen                1212
# PBC023 Bestand                    1211
# Ware eShop                        1093
# Umsatzhochrechnung                 953
# Besucherfrequenz                   884
# DB-Berichte                        734
# Umsatzindex                        696
# Investitionen                      488
# Lagerdrehung                       322
# Deichmann Jr.-Berichte             277
# Logistik                           209
# Kosten eShop                       194
# Rohertrag                          170
# Abweichungsanalyse                 167
# Tagespaarzahl                      146
# Umsatzvergl. DSD mit Branche        95
# Werbung                             60
# Tagesums. u. Paarz. n. Gebiet       27
# Bonanalyse                          11
# Reisekosten                          5
# Name: Bereich E2, dtype: int64

# %%
df['Ausprägung'].value_counts()
# Out:
# TAGROH200D              10177
# TAFIAR200_SG             7202
# Tag_Ums                  6580
# TAFIVA200_SG_1           4140
# eShop_Ums_Abs_GL         2724
#                         ...
# Leerkartonfunde_mon         1
# TOP50_Menge_Woche           1
# 11_UKL_BJ_VJ                1
# Umtausch_mon                1
# ExpRate_MYS_MAT_2019        1
# Name: Ausprägung, Length: 281, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# TAFIAR200    12066
# TAGROH200    10177
# TAFIVA200     8549
# KALKUL202     8150
# MOFIAR201     5161
# MOFIAR203     1130
# KOMWAR201     1003
# MOORAR202      831
# TAGROH201      754
# BESTAN202      712
# WAREIN200      629
# BESTAN201      489
# ALTSTR201      262
# MOFIPR205      178
# AUSREC222      124
# MOFIAR202       36
# WAREIN201       18
# Name: Name, dtype: int64

# %%
df['ZEIT'].value_counts()
# Out:
# 2021-07-27 07:09:22    6
# 2021-03-22 06:16:26    6
# 2020-09-30 16:38:14    5
# 2021-06-15 08:42:15    5
# 2020-10-05 14:10:57    5
#                       ..
# 2021-05-17 09:15:21    1
# 2021-05-17 08:37:13    1
# 2021-05-17 07:32:12    1
# 2021-05-16 15:04:39    1
# 2021-08-27 14:09:43    1
# Name: ZEIT, Length: 82639, dtype: int64

# %%
df.NR.value_counts()
# Out:
# 20719     2
# 61130     2
# 63065     2
# 62813     2
# 62751     2
#          ..
# 22688     1
# 22687     1
# 22686     1
# 22682     1
# 116653    1
# Name: NR, Length: 84715, dtype: int64

# %%
df.MONAT.value_counts()
# Out:
# 2020-09-01    9090
# 2020-10-01    8199
# 2020-11-01    7806
# 2020-12-01    7744
# 2021-06-01    7419
# 2021-05-01    6776
# 2021-01-01    6651
# 2021-03-01    6381
# 2021-07-01    6309
# 2021-04-01    6127
# 2021-08-01    5743
# 2021-02-01    5025
# 2020-08-01    3018
# Name: MONAT, dtype: int64

# %%
df['User Pseudo'].value_counts()
# Out:
# User_310    3098
# User_136    2487
# User_382    2407
# User_384    1857
# User_221    1507
#             ...
# User_332       1
# User_14        1
# User_172       1
# User_261       1
# User_141       1
# Name: User Pseudo, Length: 422, dtype: int64

# %%
df.ABTEILUNG.value_counts()
# Out:
# Einkauf                             51410
# Controlling                         14812
# Finanz- und Rechnungswesen           5695
# Werbung                              4085
# Geschäftsleitung                     3088
# eShop                                3066
# Verkauf                              2683
# Rechnungswesen                        859
# DZ D (BT), I, NL, PL, SK, TR, UK      225
# IS POS                                128
# Koordination                           52
# Revision                               50
# Bauabteilung                           40
# Rechtsabteilung                        37
# Expansion                              29
# Beschaffungslogistik                   16
# DZ CH                                   8
# POS Helpdesk                            3
# DZ D (FW)                               1
# Systembetreuung/ Entwicklung            1
# Name: ABTEILUNG, dtype: int64

# %%
df['BERICHT'].value_counts()
# Out:
# TAGROH200D.pdf              10177
# TAFIAR200_SG.pdf             7202
# Tag_Ums.pdf                  6580
# TAFIVA200_SG_1.pdf           4140
# eShop_Ums_Abs_GL.pdf         2724
#                             ...
# Leerkartonfunde_mon.pdf         1
# TOP50_Menge_Woche.pdf           1
# 11_UKL_BJ_VJ.pdf                1
# Umtausch_mon.pdf                1
# ExpRate_MYS_MAT_2019.pdf        1
# Name: BERICHT, Length: 281, dtype: int64

# %%
df.IST_KONZERNBERICHT.value_counts()
# Out:
# 0    84050
# 1     2238
# Name: IST_KONZERNBERICHT, dtype: int64

# %%
df.Anzahl.value_counts()
# Out:
# 1    86288
# Name: Anzahl, dtype: int64

# %%
df[df['Name'].isnull()== False]['BERICHT'].nunique()
# Out:
# 118

# %%
df[df['Name'].isnull()== True]['BERICHT'].nunique()
# Out:
# 163

# %%
df.ZEIT.max()
# Out:
# Timestamp('2021-08-30 15:10:37')

# %%
df.ZEIT.min()
# Out:
# Timestamp('2020-08-12 14:07:42')

# %%
df.NR.nunique()
# Out:
# 84715

# %%
df[df['BERICHT']=='TAGROH200D.pdf']['ABTEILUNG'].value_counts()
# Out:
# Einkauf                             6180
# Finanz- und Rechnungswesen          1367
# Verkauf                              850
# eShop                                839
# Controlling                          764
# Geschäftsleitung                     161
# Werbung                               10
# Rechnungswesen                         5
# DZ D (BT), I, NL, PL, SK, TR, UK       1
# Name: ABTEILUNG, dtype: int64

# %%
df[df['BERICHT']=='Tag_Ums.pdf']['ABTEILUNG'].value_counts()
# Out:
# Einkauf                             4954
# Controlling                         1057
# Finanz- und Rechnungswesen           251
# Verkauf                              153
# Werbung                               54
# eShop                                 47
# DZ D (BT), I, NL, PL, SK, TR, UK      21
# Rechnungswesen                        19
# Geschäftsleitung                      16
# Rechtsabteilung                        4
# Bauabteilung                           4
# Name: ABTEILUNG, dtype: int64

# %%
df[df['BERICHT']=='Tag_Ums.pdf']['Ausprägung'].value_counts()
# Out:
# Tag_Ums    6580
# Name: Ausprägung, dtype: int64

# %%
df[df['BERICHT']=='Tag_Ums.pdf']['Kürzel E1'].value_counts()
# Out:
# UMS    6580
# Name: Kürzel E1, dtype: int64

# %%
df[df['BERICHT']=='Tag_Ums.pdf']['Kürzel E2'].value_counts()
# Out:
# UMSTAGUMS    6580
# Name: Kürzel E2, dtype: int64

# %%
df[df['BERICHT']=='Tag_Ums.pdf']['Bereich E1'].value_counts()
# Out:
# Umsatz und Absatz    6580
# Name: Bereich E1, dtype: int64

# %%
df[df['BERICHT']=='Branche_BEVH_Umsatzindex_Jahre.pdf']
# Out:
#    Kürzel E1    Bereich E1 Kürzel E2               Bereich E2  \
# 0       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 1       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 2       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 3       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 4       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 5       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 6       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 7       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 8       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 9       ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 10      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 11      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 12      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 13      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 14      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 15      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 16      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 17      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 18      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 19      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 20      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 21      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 22      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 23      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 24      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 25      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 26      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 27      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 28      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 29      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 30      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 31      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 32      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 33      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 34      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 35      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 36      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 37      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 38      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 39      ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
#
#                         Ausprägung Name                ZEIT      NR  \
# 0   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-08-26 10:17:01    1926
# 1   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-09-22 11:02:31   13499
# 2   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 13:03:47   23214
# 3   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 15:16:31   23293
# 4   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-22 14:52:39   24745
# 5   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-11-24 11:24:30   35184
# 6   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-12-01 15:41:20   38777
# 7   Branche_BEVH_Umsatzindex_Jahre  NaN 2020-12-05 07:49:29   41329
# 8   Branche_BEVH_Umsatzindex_Jahre  NaN 2021-01-12 10:32:22   51523
# 9   Branche_BEVH_Umsatzindex_Jahre  NaN 2021-01-20 11:52:22   54134
# 10  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-01-27 13:24:34   56121
# 11  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-05 16:29:44   59316
# 12  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-09 09:46:20   59958
# 13  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-09 14:20:09   60148
# 14  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-10 12:41:03   60514
# 15  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-11 14:27:45   60932
# 16  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-17 14:58:04   62361
# 17  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-03-23 11:35:54   71687
# 18  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-03-30 16:15:46   73130
# 19  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-14 09:27:00   76885
# 20  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-14 11:46:22   77025
# 21  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-15 11:09:27   77443
# 22  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-23 11:49:20   79974
# 23  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-23 11:49:20   79975
# 24  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-23 12:46:40   79998
# 25  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-04-27 10:19:18   80702
# 26  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-05-12 08:16:02   85185
# 27  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-05-17 11:05:14   86383
# 28  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-05-26 11:08:53   89303
# 29  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-05-26 11:09:24   89306
# 30  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-06-16 13:43:40   97705
# 31  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-06-24 10:23:17   99715
# 32  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-15 15:15:02  105944
# 33  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-16 07:48:02  106003
# 34  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-19 09:10:03  106416
# 35  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-19 09:55:27  106447
# 36  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-19 10:01:40  106448
# 37  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-19 10:26:35  106493
# 38  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-19 18:13:32  106730
# 39  Branche_BEVH_Umsatzindex_Jahre  NaN 2021-07-20 12:43:49  106950
#
#         MONAT User Pseudo                         ABTEILUNG  \
# 0  2020-08-01    User_104                           Einkauf
# 1  2020-09-01    User_404                           Einkauf
# 2  2020-10-01     User_85                       Controlling
# 3  2020-10-01    User_206                       Controlling
# 4  2020-10-01     User_85                       Controlling
# 5  2020-11-01     User_85                       Controlling
# 6  2020-12-01     User_53                       Controlling
# 7  2020-12-01     User_25                           Einkauf
# 8  2021-01-01    User_404                           Einkauf
# 9  2021-01-01    User_252                           Werbung
# 10 2021-01-01     User_85                       Controlling
# 11 2021-02-01    User_206                       Controlling
# 12 2021-02-01     User_10                           Einkauf
# 13 2021-02-01    User_206                       Controlling
# 14 2021-02-01     User_85                       Controlling
# 15 2021-02-01     User_85                       Controlling
# 16 2021-02-01    User_206                       Controlling
# 17 2021-03-01    User_317                           Einkauf
# 18 2021-03-01     User_85                       Controlling
# 19 2021-04-01    User_148  DZ D (BT), I, NL, PL, SK, TR, UK
# 20 2021-04-01     User_85                       Controlling
# 21 2021-04-01     User_85                       Controlling
# 22 2021-04-01    User_206                       Controlling
# 23 2021-04-01    User_206                       Controlling
# 24 2021-04-01    User_398                           Einkauf
# 25 2021-04-01     User_85                       Controlling
# 26 2021-05-01     User_41                       Controlling
# 27 2021-05-01     User_85                       Controlling
# 28 2021-05-01    User_357                           Einkauf
# 29 2021-05-01    User_357                           Einkauf
# 30 2021-06-01    User_143                             eShop
# 31 2021-06-01     User_85                       Controlling
# 32 2021-07-01     User_85                       Controlling
# 33 2021-07-01     User_29                       Controlling
# 34 2021-07-01     User_85                       Controlling
# 35 2021-07-01     User_29                       Controlling
# 36 2021-07-01     User_29                       Controlling
# 37 2021-07-01     User_29                       Controlling
# 38 2021-07-01     User_85                       Controlling
# 39 2021-07-01    User_278                          Revision
#
#                                BERICHT  IST_KONZERNBERICHT  Anzahl
# 0   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 1   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 2   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 3   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 4   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 5   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 6   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 7   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 8   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 9   Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 10  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 11  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 12  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 13  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 14  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 15  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 16  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 17  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 18  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 19  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 20  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 21  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 22  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 23  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 24  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 25  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 26  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 27  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 28  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 29  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 30  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 31  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 32  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 33  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 34  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 35  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 36  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 37  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 38  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1
# 39  Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1

# %%
df[df['User Pseudo']=='User_310']['MONAT'].value_counts()
# Out:
# 2021-07-01    460
# 2020-10-01    349
# 2020-09-01    302
# 2021-02-01    272
# 2020-11-01    267
# 2021-06-01    232
# 2020-12-01    231
# 2021-04-01    185
# 2021-05-01    184
# 2021-08-01    167
# 2021-03-01    162
# 2021-01-01    159
# 2020-08-01    128
# Name: MONAT, dtype: int64

# %%
df['NR'].sort_values()
# Out:
# 46516        39
# 34259        84
# 34260        85
# 51127        86
# 46517        87
#           ...
# 63395    117097
# 86029    117099
# 60641    117100
# 63396    117101
# 28968    117102
# Name: NR, Length: 86288, dtype: int64

# %%
df[df['ABTEILUNG']=='Einkauf']
# Out:
#       Kürzel E1    Bereich E1 Kürzel E2               Bereich E2  \
# 0          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 1          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 7          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 8          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 12         ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# ...         ...           ...       ...                      ...
# 86160       ERG      Ergebnis    ERGROH                Rohertrag
# 86223       ERG      Ergebnis    ERGROH                Rohertrag
# 86227       ERG      Ergebnis    ERGROH                Rohertrag
# 86234       ERG      Ergebnis    ERGROH                Rohertrag
# 86287       ERG      Ergebnis    ERGROH                Rohertrag
#
#                            Ausprägung Name                ZEIT      NR  \
# 0      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-08-26 10:17:01    1926
# 1      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-09-22 11:02:31   13499
# 7      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-12-05 07:49:29   41329
# 8      Branche_BEVH_Umsatzindex_Jahre  NaN 2021-01-12 10:32:22   51523
# 12     Branche_BEVH_Umsatzindex_Jahre  NaN 2021-02-09 09:46:20   59958
# ...                               ...  ...                 ...     ...
# 86160                       Rohertrag  NaN 2020-09-29 09:08:08   16116
# 86223                       Rohertrag  NaN 2021-02-05 15:07:20   59237
# 86227                       Rohertrag  NaN 2021-02-16 13:16:44   62022
# 86234                       Rohertrag  NaN 2021-03-08 13:44:27   66866
# 86287                       Rohertrag  NaN 2021-08-27 14:09:43  116653
#
#            MONAT User Pseudo ABTEILUNG                             BERICHT  \
# 0     2020-08-01    User_104   Einkauf  Branche_BEVH_Umsatzindex_Jahre.pdf
# 1     2020-09-01    User_404   Einkauf  Branche_BEVH_Umsatzindex_Jahre.pdf
# 7     2020-12-01     User_25   Einkauf  Branche_BEVH_Umsatzindex_Jahre.pdf
# 8     2021-01-01    User_404   Einkauf  Branche_BEVH_Umsatzindex_Jahre.pdf
# 12    2021-02-01     User_10   Einkauf  Branche_BEVH_Umsatzindex_Jahre.pdf
# ...          ...         ...       ...                                 ...
# 86160 2020-09-01     User_74   Einkauf                       Rohertrag.pdf
# 86223 2021-02-01    User_128   Einkauf                       Rohertrag.pdf
# 86227 2021-02-01    User_233   Einkauf                       Rohertrag.pdf
# 86234 2021-03-01    User_233   Einkauf                       Rohertrag.pdf
# 86287 2021-08-01    User_233   Einkauf                       Rohertrag.pdf
#
#        IST_KONZERNBERICHT  Anzahl
# 0                       0       1
# 1                       0       1
# 7                       0       1
# 8                       0       1
# 12                      0       1
# ...                   ...     ...
# 86160                   0       1
# 86223                   0       1
# 86227                   0       1
# 86234                   0       1
# 86287                   0       1
#
# [51410 rows x 14 columns]

# %%
df['UHR']=df['ZEIT'].dt.hour

# %%
df.UHR.value_counts()
# Out:
# 8     15105
# 9     13520
# 10     9687
# 11     7998
# 13     6475
# 14     6372
# 7      5791
# 12     5560
# 15     5337
# 16     4411
# 17     2210
# 6      1097
# 18      993
# 21      376
# 19      351
# 20      344
# 22      308
# 5       132
# 23      118
# 0        46
# 4        24
# 3        13
# 1        11
# 2         9
# Name: UHR, dtype: int64

# %%
df['Arbeitszeit'] = df.loc[(df['UHR'] < 18) & (df['UHR'] >= 6),'UHR']

# %%
df.Arbeitszeit = df.Arbeitszeit.fillna(0)

# %%
df.Arbeitszeit = df.Arbeitszeit.astype(bool)

# %%
df.Arbeitszeit.value_counts()
# Out:
# True     83563
# False     2725
# Name: Arbeitszeit, dtype: int64

# %%
df.rename(columns={'Arbeitszeit':'IST_ARBEITSZEIT'},inplace=True)

# %%
df[df['IST_ARBEITSZEIT'] == False]['User Pseudo'].value_counts().head(10)
# Mitarbeiter, die am meisten außerhalb der Arbeitszeit arbeiten
# Out:
# User_351    294
# User_73     223
# User_382    113
# User_280     92
# User_402     92
# User_390     89
# User_251     73
# User_96      67
# User_136     67
# User_133     62
# Name: User Pseudo, dtype: int64

# %%
df
# Out:
#       Kürzel E1    Bereich E1 Kürzel E2               Bereich E2  \
# 0          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 1          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 2          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 3          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 4          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# ...         ...           ...       ...                      ...
# 86283       ERG      Ergebnis    ERGROH                Rohertrag
# 86284       ERG      Ergebnis    ERGROH                Rohertrag
# 86285       ERG      Ergebnis    ERGROH                Rohertrag
# 86286       ERG      Ergebnis    ERGROH                Rohertrag
# 86287       ERG      Ergebnis    ERGROH                Rohertrag
#
#                            Ausprägung Name                ZEIT      NR  \
# 0      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-08-26 10:17:01    1926
# 1      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-09-22 11:02:31   13499
# 2      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 13:03:47   23214
# 3      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 15:16:31   23293
# 4      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-22 14:52:39   24745
# ...                               ...  ...                 ...     ...
# 86283                       Rohertrag  NaN 2021-07-29 14:43:05  109045
# 86284                       Rohertrag  NaN 2021-07-29 15:22:45  109082
# 86285                       Rohertrag  NaN 2021-08-16 09:27:11  113274
# 86286                       Rohertrag  NaN 2021-08-16 23:00:25  113658
# 86287                       Rohertrag  NaN 2021-08-27 14:09:43  116653
#
#            MONAT User Pseudo                   ABTEILUNG  \
# 0     2020-08-01    User_104                     Einkauf
# 1     2020-09-01    User_404                     Einkauf
# 2     2020-10-01     User_85                 Controlling
# 3     2020-10-01    User_206                 Controlling
# 4     2020-10-01     User_85                 Controlling
# ...          ...         ...                         ...
# 86283 2021-07-01    User_287                 Controlling
# 86284 2021-07-01    User_287                 Controlling
# 86285 2021-08-01    User_290  Finanz- und Rechnungswesen
# 86286 2021-08-01     User_80                     Verkauf
# 86287 2021-08-01    User_233                     Einkauf
#
#                                   BERICHT  IST_KONZERNBERICHT  Anzahl  UHR  \
# 0      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   10
# 1      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   11
# 2      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   13
# 3      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   15
# 4      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   14
# ...                                   ...                 ...     ...  ...
# 86283                       Rohertrag.pdf                   0       1   14
# 86284                       Rohertrag.pdf                   0       1   15
# 86285                       Rohertrag.pdf                   0       1    9
# 86286                       Rohertrag.pdf                   0       1   23
# 86287                       Rohertrag.pdf                   0       1   14
#
#        IST_ARBEITSZEIT
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ...                ...
# 86283             True
# 86284             True
# 86285             True
# 86286            False
# 86287             True
#
# [86288 rows x 16 columns]

# %%
df['DAY']=df['ZEIT'].dt.dayofweek
df[['DAY','ZEIT']].sort_values(by='ZEIT')
# Out:
#        DAY                ZEIT
# 46516    2 2020-08-12 14:07:42
# 34259    4 2020-08-21 10:21:06
# 34260    4 2020-08-21 10:21:20
# 51127    4 2020-08-21 12:15:47
# 46517    4 2020-08-21 12:44:00
# ...    ...                 ...
# 63395    0 2021-08-30 15:00:08
# 86029    0 2021-08-30 15:02:56
# 60641    0 2021-08-30 15:04:23
# 63396    0 2021-08-30 15:05:43
# 28968    0 2021-08-30 15:10:37
#
# [86288 rows x 2 columns]

# %% [markdown]
# ZEITLICHE ERKENNTNISSE

# %%
df[(df['DAY']==5)]['DAY'].count()
# Out:
# 982

# %%
df[(df['DAY']==6)]['DAY'].count()
# Out:
# 1551

# %%
(982+1551)/86288 
# Prozentsatz der Aufruf, die über das Wochenende gestellt wurden
# Out:
# 0.029355182644168365

# %%
df.DAY.value_counts()
# cause of monday syndrome!
# Out:
# 0    21655
# 1    17727
# 2    15886
# 3    15505
# 4    12982
# 6     1551
# 5      982
# Name: DAY, dtype: int64

# %%
sns.lineplot(x=df['MONAT'].unique(),y=df.groupby('MONAT')['MONAT'].count().values)
sns.set(rc = {'figure.figsize':(20,10)})
plt.xticks(df['MONAT'].unique(),rotation=90);
# Verteilung nach Monaten

# %%
sns.lineplot(x=df['UHR'].unique(),y=df.groupby('UHR')['UHR'].count().values)
sns.set(rc = {'figure.figsize':(20,5)})
plt.xticks(np.arange(0, 23, step=1),rotation=0);
# Verteilung nach Uhr

# %%
df['IST_ARBEITSZEIT'].value_counts()
# Out:
# True     83563
# False     2725
# Name: IST_ARBEITSZEIT, dtype: int64

# %%
plt.pie(df['IST_ARBEITSZEIT'].value_counts(), 
        labels=['ARBEITSZEIT', 'KEINE ARBEITSZEIT'], 
        autopct="%.1f",
        radius=1.2);

# %% [markdown]
# ERKENNTNISSE ÜBER BEREICH

# %%
df['Bereich E1'].value_counts()
# Out:
# Ware                 42950
# Umsatz und Absatz    29053
# eShop-Portal          9015
# Kosten                3143
# Ergebnis              2127
# Name: Bereich E1, dtype: int64

# %%
sns.set()
plt.figure(figsize=(10,6))
sns.countplot(x='Bereich E1' ,data=df)
plt.xticks(size=12);

# %%
sns.set()
plt.figure(figsize=(10,6))
sns.countplot(x='Bereich E2', data=df)
plt.xticks(size=10,rotation=90);

# %%
df['ABTEILUNG'].value_counts()
# Von welcher Abteilung wie viele Aufrufe wurden gemacht
# Out:
# Einkauf                             51410
# Controlling                         14812
# Finanz- und Rechnungswesen           5695
# Werbung                              4085
# Geschäftsleitung                     3088
# eShop                                3066
# Verkauf                              2683
# Rechnungswesen                        859
# DZ D (BT), I, NL, PL, SK, TR, UK      225
# IS POS                                128
# Koordination                           52
# Revision                               50
# Bauabteilung                           40
# Rechtsabteilung                        37
# Expansion                              29
# Beschaffungslogistik                   16
# DZ CH                                   8
# POS Helpdesk                            3
# DZ D (FW)                               1
# Systembetreuung/ Entwicklung            1
# Name: ABTEILUNG, dtype: int64

# %%
sns.set()
sns.countplot(x='ABTEILUNG', data = df)
plt.xticks(size=10,rotation=90);

# %%
df.groupby('ABTEILUNG')['User Pseudo'].nunique().sort_values(ascending=False)
# Anzahl der User nach der Abteilung
# Out:
# ABTEILUNG
# Einkauf                             200
# Controlling                          42
# Verkauf                              40
# Finanz- und Rechnungswesen           38
# Werbung                              36
# Geschäftsleitung                     17
# eShop                                12
# Rechnungswesen                       10
# DZ D (BT), I, NL, PL, SK, TR, UK      5
# Revision                              5
# Rechtsabteilung                       5
# IS POS                                3
# Bauabteilung                          2
# POS Helpdesk                          1
# Koordination                          1
# Beschaffungslogistik                  1
# Expansion                             1
# Systembetreuung/ Entwicklung          1
# DZ D (FW)                             1
# DZ CH                                 1
# Name: User Pseudo, dtype: int64

# %%
sns.set()
sns.barplot(y = df.groupby('ABTEILUNG')['User Pseudo'].nunique().values,x=df.groupby('ABTEILUNG')[['User Pseudo']].nunique().index)
plt.xticks(size=10,rotation=90);

# %%
df['User Pseudo'].sort_values(ascending=False)
# Out:
# 24371    User_99
# 46274    User_99
# 29378    User_99
# 46891    User_99
# 30280    User_99
#           ...
# 59427     User_1
# 59413     User_1
# 59412     User_1
# 59351     User_1
# 60327     User_1
# Name: User Pseudo, Length: 86288, dtype: object

# %%
df
# Out:
#       Kürzel E1    Bereich E1 Kürzel E2               Bereich E2  \
# 0          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 1          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 2          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 3          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# 4          ESHP  eShop-Portal    ESHUMS  Umsatz und Absatz eShop
# ...         ...           ...       ...                      ...
# 86283       ERG      Ergebnis    ERGROH                Rohertrag
# 86284       ERG      Ergebnis    ERGROH                Rohertrag
# 86285       ERG      Ergebnis    ERGROH                Rohertrag
# 86286       ERG      Ergebnis    ERGROH                Rohertrag
# 86287       ERG      Ergebnis    ERGROH                Rohertrag
#
#                            Ausprägung Name                ZEIT      NR  \
# 0      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-08-26 10:17:01    1926
# 1      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-09-22 11:02:31   13499
# 2      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 13:03:47   23214
# 3      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-16 15:16:31   23293
# 4      Branche_BEVH_Umsatzindex_Jahre  NaN 2020-10-22 14:52:39   24745
# ...                               ...  ...                 ...     ...
# 86283                       Rohertrag  NaN 2021-07-29 14:43:05  109045
# 86284                       Rohertrag  NaN 2021-07-29 15:22:45  109082
# 86285                       Rohertrag  NaN 2021-08-16 09:27:11  113274
# 86286                       Rohertrag  NaN 2021-08-16 23:00:25  113658
# 86287                       Rohertrag  NaN 2021-08-27 14:09:43  116653
#
#            MONAT User Pseudo                   ABTEILUNG  \
# 0     2020-08-01    User_104                     Einkauf
# 1     2020-09-01    User_404                     Einkauf
# 2     2020-10-01     User_85                 Controlling
# 3     2020-10-01    User_206                 Controlling
# 4     2020-10-01     User_85                 Controlling
# ...          ...         ...                         ...
# 86283 2021-07-01    User_287                 Controlling
# 86284 2021-07-01    User_287                 Controlling
# 86285 2021-08-01    User_290  Finanz- und Rechnungswesen
# 86286 2021-08-01     User_80                     Verkauf
# 86287 2021-08-01    User_233                     Einkauf
#
#                                   BERICHT  IST_KONZERNBERICHT  Anzahl  UHR  \
# 0      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   10
# 1      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   11
# 2      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   13
# 3      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   15
# 4      Branche_BEVH_Umsatzindex_Jahre.pdf                   0       1   14
# ...                                   ...                 ...     ...  ...
# 86283                       Rohertrag.pdf                   0       1   14
# 86284                       Rohertrag.pdf                   0       1   15
# 86285                       Rohertrag.pdf                   0       1    9
# 86286                       Rohertrag.pdf                   0       1   23
# 86287                       Rohertrag.pdf                   0       1   14
#
#        IST_ARBEITSZEIT  DAY
# 0                 True    2
# 1                 True    1
# 2                 True    4
# 3                 True    4
# 4                 True    3
# ...                ...  ...
# 86283             True    3
# 86284             True    3
# 86285             True    0
# 86286            False    0
# 86287             True    4
#
# [86288 rows x 17 columns]

# %%
df['User Pseudo'].value_counts().head()
# Out:
# User_310    3098
# User_136    2487
# User_382    2407
# User_384    1857
# User_221    1507
# Name: User Pseudo, dtype: int64
